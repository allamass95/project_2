# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
connection_string = "postgres:Alevaporo58@localhost:5432/project_2"
engine = create_engine(f'postgresql://{connection_string}')

# %%
file=pd.read_csv('/Users/alejandrollamas/Desktop/HW-Bootcamp/HW Assignments/Project2/data/2011_data.csv',header=-1)
data=file
file_2013=pd.read_csv('/Users/alejandrollamas/Desktop/HW-Bootcamp/HW Assignments/Project2/data/2013_data.csv',header=-1)
data_2013=file_2013

# %%
data.head()
# Out:
#         state  total_seats  total_senate  senate_dem  senate_rep  \
# 0     Alabama          140            35          12        22.0
# 1      Alaska           60            20          10        10.0
# 2     Arizona           90            30           9        21.0
# 3    Arkansas          135            35          20        15.0
# 4  California          120            40          25        15.0
#
#    senate_other  total_house  house_dem  house_rep  house_other legis_control  \
# 0           1.0        105.0       39.0       66.0          0.0           Rep
# 1           0.0         40.0       16.0       24.0          0.0         Split
# 2           0.0         60.0       20.0       40.0          0.0           Rep
# 3           0.0        100.0       55.0       44.0          NaN           Dem
# 4           0.0         80.0       52.0       28.0          0.0           Dem
#
#   gov_party state_control
# 0       Rep           Rep
# 1       Rep       Divided
# ...

# %%
data=data.rename(columns={0:'state',1:'total_seats',2:'total_senate',3:'senate_dem',4:'senate_rep',
                          5:'senate_other',6:'total_house',7:'house_dem',8:'house_rep',9:'house_other',10:'legis_control',11:'gov_party',12:'state_control'})

# %%
data[data.columns[1:10]]=data[data.columns[1:10]].convert_objects(convert_numeric=True).fillna(0).astype(int)
# Out:
# /Users/alejandrollamas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
data.head()
# Out:
#         state  total_seats  total_senate  senate_dem  senate_rep  \
# 0     Alabama          140            35          12          22
# 1      Alaska           60            20          10          10
# 2     Arizona           90            30           9          21
# 3    Arkansas          135            35          20          15
# 4  California          120            40          25          15
#
#    senate_other  total_house  house_dem  house_rep  house_other legis_control  \
# 0             1          105         39         66            0           Rep
# 1             0           40         16         24            0         Split
# 2             0           60         20         40            0           Rep
# 3             0          100         55         44            0           Dem
# 4             0           80         52         28            0           Dem
#
#   gov_party state_control
# 0       Rep           Rep
# 1       Rep       Divided
# ...

# %%
data.to_csv('data_2011.csv',index=False)

# %%
def clean_data(data,table_name):
    data=data.rename(columns={0:'state',1:'total_seats',2:'total_senate',
                              3:'senate_dem',4:'senate_rep',
                              5:'senate_other',6:'total_house',
                              7:'house_dem',8:'house_rep',9:'house_other',
                              10:'legis_control',11:'gov_party',12:'state_control'})
    data[data.columns[1:10]]=data[data.columns[1:10]].convert_objects(convert_numeric=True).fillna(0).astype(int)
    
    data.to_sql(name=table_name,con=engine, if_exists='append', index=False)

# %%
clean_data(data_2013,'data_2013')
# Out:
# /Users/alejandrollamas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   import sys
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     353         if not self._use_threadlocal:
# --> 354             return _ConnectionFairy._checkout(self)
#     355
#
# ...

# %%
data.to_csv('data_2013.csv',index=False)
